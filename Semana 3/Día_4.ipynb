# %%
import pandas as pd

# %%
datos = [100, 200, 150, 50]
serie = pd.Series(datos)

# %%
print(serie.mean())
# Out:
# 125.0

# %%
print(serie.sum())
# Out:
# 500

# %%
print(serie.max())
# Out:
# 200

# %%
print(serie.min())
# Out:
# 50
