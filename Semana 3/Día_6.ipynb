# %%
import pandas as pd

datos = [1200, 1300, 1250, 1400, 1500]
df = pd.Series(datos)

print("Media:", df.mean())
print("Máximo:", df.max())
print("Mínimo:", df.min())
# Out:
# Media: 1330.0
# Máximo: 1500
# Mínimo: 1200
