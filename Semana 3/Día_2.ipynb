# %%
ventas = [120, 150, 90, 200, 175, 110]
total = sum(ventas)
media = total/len(ventas)
maximo = max(ventas)
minimo = min(ventas)
print("Total=", total)
print("Media=", media)
print("Máximo=", maximo)
print("Mínimo=", minimo)
# Out:
# Total= 845
# Media= 140.83333333333334
# Máximo= 200
# Mínimo= 90
