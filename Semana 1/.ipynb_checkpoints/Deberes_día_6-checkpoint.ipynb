# %%
gasto = [200, 300, 30, 75, 400, 113]
suma = 0
for g in gasto:
    suma = suma + g
    print(suma)
# Out:
# 200
# 500
# 530
# 605
# 1005
# 1118

# %%
1118//5
# Out:
# 223

# %%
Total gastos = 1118
Gasto medio = 223
