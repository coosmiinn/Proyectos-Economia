# %%
precios = [5, 10, 15, 20]
suma = 0
for p in precios:
    suma = suma + p

# %%
print(suma)
# Out:
# 50

# %%
salarios = [1000, 1200, 1100, 900]
suma = 0
for s in salarios:
    suma = suma + s

# %%
print(suma)
# Out:
# 4200

# %%
suma = 0
for x in [1, 2, 3]:
    suma += x

# %%
print(suma)
# Out:
# 6
