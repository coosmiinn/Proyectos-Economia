# %%
salarios = [1200, 1500, 980, 2000, 1750]
print(max(salarios))
# Out:
# 2000

# %%
print(min(salarios))
# Out:
# 980

# %%
paro = [12.3, 11.8, 13.1, 10.0]
print(min(paro))
# Out:
# 10.0

# %%
print(max(paro))
# Out:
# 13.1
