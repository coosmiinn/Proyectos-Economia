# %%
gastos =[350, 120, 80, 200, 60, 90, 150]
total = 0
for g in gastos:
    total += g

# %%
print(total)
# Out:
# 1050

# %%
print(len(gastos))
# Out:
# 7

# %%
media = suma/len(gastos)
print(media)
# Out:
# 150.0

# %%
print(max(gastos))
# Out:
# 350

# %%
print(min(gastos))
# Out:
# 60

# %%
print("Mi gasto más alto fue 350")
print("Mi gasto más bajo fue 60")
# Out:
# Mi gasto más alto fue 350
# Mi gasto más bajo fue 60

# %%
print("Total:", total)
print("Gasto medio:", media)
print("Gasto más alto:", max(gastos))
print("Gasto más bajo:", min(gastos))
print("Nº de gatos:", len(gastos))
# Out:
# Total: 1050
# Gasto medio: 150.0
# Gasto más alto: 350
# Gasto más bajo: 60
# Nº de gatos: 7
