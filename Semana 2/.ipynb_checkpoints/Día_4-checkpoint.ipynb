# %%
paises = ["España", "Francia", "Italia", "Portugal"]
print(len(paises))
# Out:
# 4

# %%
tipos_interes = [2.5, 3.0, 3.5, 4.0, 4.25]
print(len(tipos_interes))
# Out:
# 5

# %%
receta = ["leche","huevos","azucar","miel","harina","canela"]
print(len(receta))
# Out:
# 6
