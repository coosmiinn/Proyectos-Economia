# %%
gastos = [100, 200, 150, 50]
suma = 0
for g in gastos:
    suma += g

# %%
print(suma)
# Out:
# 500

# %%
total = 500
x = 4
print(total/x)
# Out:
# 125.0

# %%
media = 125
print(media)
# Out:
# 125
