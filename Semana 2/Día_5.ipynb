# %%
ventas = [120, 150, 90, 200, 175, 110]
suma = 0
for v in ventas:
    suma += v

# %%
print(suma)
# Out:
# 845

# %%
846//6
# Out:
# 141

# %%
print(max(ventas))
# Out:
# 200

# %%
print(min(ventas))
# Out:
# 90

# %%
print(len(ventas))
# Out:
# 6

# %%
print("Total:", 845)
print("Media:", 141)
print("Máximo:", 200)
print("Mínimo:", 90)
print("Número de datos:", 6)
# Out:
# Total: 845
# Media: 141
# Máximo: 200
# Mínimo: 90
# Número de datos: 6
