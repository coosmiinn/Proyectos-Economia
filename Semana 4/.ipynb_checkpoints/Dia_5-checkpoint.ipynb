# %%
import pandas as pd

datos = { 
    "Paises" : ["España", "Portugal", "Francia"],
    "PIB" : [2000, 2300, 2800]
}

df = pd.DataFrame(datos)

print(df[df["PIB"] > 2300])
# Out:
#     Paises   PIB
# 2  Francia  2800
