# %%
import pandas as pd

datos = {
    "Paises" : ["España", "Portugal", "Italia"],
    "PIB" : [2000, 1700, 2300]
}

df = pd.DataFrame(datos)

print(df["PIB"])
# Out:
# 0    2000
# 1    1700
# 2    2300
# Name: PIB, dtype: int64

# %%
print(df["Paises"])
# Out:
# 0      España
# 1    Portugal
# 2      Italia
# Name: Paises, dtype: str
