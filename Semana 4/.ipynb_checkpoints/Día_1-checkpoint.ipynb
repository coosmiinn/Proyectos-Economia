# %%
import pandas as pd
datos = {
    "País": ["Japón", "China", "EEUU"],
    "PIB": [ 3800, 2000, 2500]
}

df = pd.DataFrame(datos)

print(df)
# Out:
#     País   PIB
# 0  Japón  3800
# 1  China  2000
# 2   EEUU  2500
