# %%
import pandas as pd

datos = { 
    "Paises" : ["España", "Portugal", "Francia"],
    "PIB" : [2000, 2300, 2800]
}

df = pd.DataFrame(datos)

print(df["PIB"].mean())
print(df["PIB"].max())
# Out:
# 2366.6666666666665
# 2800
