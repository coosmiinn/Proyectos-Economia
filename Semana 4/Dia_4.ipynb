# %%
import pandas as pd

datos = { 
    "Paises" : ["España", "Portugal", "Francia"],
    "PIB" : [2000, 2300, 2800]
}

df = pd.DataFrame(datos)

df["PIB_per_capita"] = [12000, 23000, 40000]

print(df)
# Out:
#      Paises   PIB  PIB_per_capita
# 0    España  2000           12000
# 1  Portugal  2300           23000
# 2   Francia  2800           40000
